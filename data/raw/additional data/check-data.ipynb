# %%
import numpy as np
import pandas as pd

pd.options.display.max_rows = 4000
pd.options.display.max_seq_items = 2000
pd.set_option('display.max_columns', None)

# %% [markdown]
# # listings

# %%
listings = pd.read_csv('listings.csv')
listings.head()
# Out:
#        id                                            name  host_id
# 0   27934                 Nice room with superb city view   120437  \
# 1   27979                  Easy going landlord,easy place   120541
# 2   28745               modern-style apartment in Bangkok   123784
# 3   35780  Spacious one bedroom at The Kris Condo Bldg. 3   153730
# 4  941865                      Suite Room 3 at MetroPoint   610315
#
#     host_name  neighbourhood_group neighbourhood  latitude  longitude
# 0      Nuttee                  NaN   Ratchathewi  13.75983  100.54134  \
# 1         Emy                  NaN       Bang Na  13.66818  100.61674
# 2  Familyroom                  NaN     Bang Kapi  13.75232  100.62402
# 3     Sirilak                  NaN     Din Daeng  13.78823  100.57256
# 4       Kasem                  NaN     Bang Kapi  13.76872  100.63338
#
#          room_type  price  minimum_nights  number_of_reviews last_review
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15854 entries, 0 to 15853
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15854 non-null  int64
#  1   name                            15846 non-null  object
#  2   host_id                         15854 non-null  int64
#  3   host_name                       15853 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   15854 non-null  object
#  6   latitude                        15854 non-null  float64
#  7   longitude                       15854 non-null  float64
#  8   room_type                       15854 non-null  object
#  9   price                           15854 non-null  int64
#  10  minimum_nights                  15854 non-null  int64
#  11  number_of_reviews               15854 non-null  int64
# ...

# %% [markdown]
# # listings2

# %%
lastReviewDate = pd.to_datetime(listings.last_review)

display(lastReviewDate.min(), lastReviewDate.max())
# Out:
# Timestamp('2012-12-15 00:00:00')
# Timestamp('2022-12-28 00:00:00')

# %%
listings2 = pd.read_csv('listings2.csv')
listings2.head()
# Out:
#        id                          listing_url       scrape_id last_scraped
# 0   27934   https://www.airbnb.com/rooms/27934  20221228025833   2022-12-28  \
# 1  941865  https://www.airbnb.com/rooms/941865  20221228025833   2022-12-28
# 2   27979   https://www.airbnb.com/rooms/27979  20221228025833   2022-12-28
# 3   28745   https://www.airbnb.com/rooms/28745  20221228025833   2022-12-28
# 4   35780   https://www.airbnb.com/rooms/35780  20221228025833   2022-12-28
#
#         source                                            name
# 0  city scrape                 Nice room with superb city view  \
# 1  city scrape                      Suite Room 3 at MetroPoint
# 2  city scrape                  Easy going landlord,easy place
# 3  city scrape               modern-style apartment in Bangkok
# 4  city scrape  Spacious one bedroom at The Kris Condo Bldg. 3
#
#                                          description
# 0  Our cool and comfortable one bedroom apartment...  \
# ...

# %%
listings2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15854 entries, 0 to 15853
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            15854 non-null  int64
#  1   listing_url                                   15854 non-null  object
#  2   scrape_id                                     15854 non-null  int64
#  3   last_scraped                                  15854 non-null  object
#  4   source                                        15854 non-null  object
#  5   name                                          15846 non-null  object
#  6   description                                   15248 non-null  object
#  7   neighborhood_overview                         8375 non-null   object
#  8   picture_url                                   15854 non-null  object
# ...

# %%
price = listings2.price.str.strip('$').str.replace(',','').astype(float)
price.max()
# Out:
# 1100000.0

# %%
listings2.property_type.value_counts()
# Out:
# property_type
# Entire condo                          3771
# Entire rental unit                    3769
# Private room in rental unit           1601
# Private room in condo                  876
# Room in hotel                          695
# Room in boutique hotel                 534
# Private room in home                   531
# Entire home                            420
# Private room in hostel                 382
# Private room in townhouse              373
# Entire serviced apartment              330
# Private room in serviced apartment     317
# Shared room in hostel                  317
# Entire townhouse                       292
# Private room in bed and breakfast      268
# Room in hostel                         189
# Room in aparthotel                     138
# Private room                           111
# Room in serviced apartment              95
# Entire loft                             92
# Private room in guesthouse              79
# ...

# %%
listings2.amenities.unique()
# Out:
# array(['["Shampoo", "Kitchen", "Fire extinguisher", "Free parking on premises", "Long term stays allowed", "Elevator", "Hot water", "Pool", "Dishes and silverware", "Dryer", "Essentials", "Wifi", "Microwave", "Smoke alarm", "Host greets you", "Hair dryer", "Luggage dropoff allowed", "Washer", "Patio or balcony", "TV", "Air conditioning", "Stove", "Gym", "Iron", "Hangers", "Refrigerator"]',
#        '["Washer", "Air conditioning", "Breakfast", "Kitchen", "Dryer", "Wifi", "TV with standard cable", "Free parking on premises", "Long term stays allowed", "Elevator"]',
#        '["Pool", "Washer", "First aid kit", "Heating", "Shampoo", "Gym", "Kitchen", "Essentials", "Wifi", "Fire extinguisher", "TV with standard cable", "Free parking on premises", "Smoke alarm", "Long term stays allowed", "Hot tub", "Elevator"]',
#        ...,
# ...

# %%
listings2.accommodates.unique()
# Out:
# array([ 3,  2,  4,  5,  1, 16, 12, 13,  6,  8,  7, 11, 10, 14,  9, 15,  0],
#       dtype=int64)

# %% [markdown]
# # calendar

# %%
calendar = pd.read_csv('calendar2.csv')
calendar.head()
# Out:
#    listing_id        date available      price adjusted_price  minimum_nights
# 0       27934  2022-12-28         f  $1,905.00      $1,905.00               3  \
# 1       27934  2022-12-29         f  $1,905.00      $1,905.00               3
# 2       27934  2022-12-30         f  $1,905.00      $1,905.00               3
# 3       27934  2022-12-31         f  $1,905.00      $1,905.00               3
# 4       27934  2023-01-01         f  $1,905.00      $1,905.00               3
#
#    maximum_nights
# 0              90
# 1              90
# 2              90
# 3              90
# 4              90

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5786345 entries, 0 to 5786344
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  object
#  5   minimum_nights  int64
#  6   maximum_nights  int64
# dtypes: int64(3), object(4)
# memory usage: 309.0+ MB

# %%
calendar.date = pd.to_datetime(calendar.date)
display(calendar.date.min(), calendar.date.max())
# Out:
# Timestamp('2022-12-28 00:00:00')
# Timestamp('2024-01-02 00:00:00')

# %% [markdown]
# # reviews

# %%
reviews = pd.read_csv('reviews.csv')
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name
# 0       27934  1094339  2012-04-07      1368195       Michael  \
# 1       27934  1241042  2012-05-07      2007324         Scott
# 2       27934  1523384  2012-06-20      2263352          Marc
# 3       27934  1655571  2012-07-08       558987         Leyla
# 4       27934  1972192  2012-08-13      2359865        Rachel
#
#                                             comments
# 0  We stayed in the apartment for a week and we e...
# 1  My girlfriend and I recently stayed in Nuttee'...
# 2  I stayed for one month at the condo and was re...
# 3  Nuttee was a great host! I really enjoyed her ...
# 4  Nuttee was an amazing host. She and her daught...
